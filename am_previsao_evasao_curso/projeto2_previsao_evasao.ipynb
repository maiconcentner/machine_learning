# %% [markdown]
# # Análise rápida dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base_eventos = pd.read_csv("event_data_train.csv")
base_submissao = pd.read_csv("submissions_data_train.csv")

# %%
base_eventos.head()
# Out:
#    step_id   timestamp      action  user_id
# 0    32815  1434340848      viewed    17632
# 1    32815  1434340848      passed    17632
# 2    32815  1434340848  discovered    17632
# 3    32811  1434340895  discovered    17632
# 4    32811  1434340895      viewed    17632

# %%
base_submissao.head()
# Out:
#    step_id   timestamp submission_status  user_id
# 0    31971  1434349275           correct    15853
# 1    31972  1434348300           correct    15853
# 2    31972  1478852149             wrong    15853
# 3    31972  1478852164           correct    15853
# 4    31976  1434348123             wrong    15853

# %%
base_eventos.describe()
# Out:
#             step_id     timestamp       user_id
# count  3.480703e+06  3.480703e+06  3.480703e+06
# mean   3.487358e+04  1.480288e+09  1.331468e+04
# std    1.422243e+04  3.068906e+07  7.779099e+03
# min    3.045600e+04  1.434341e+09  1.000000e+00
# 25%    3.217900e+04  1.450271e+09  6.642000e+03
# 50%    3.292900e+04  1.483904e+09  1.320800e+04
# 75%    3.348100e+04  1.507889e+09  2.014400e+04
# max    1.584330e+05  1.526773e+09  2.679800e+04

# %%
len(base_eventos)
# Out:
# 3480703

# %%
len(base_submissao)
# Out:
# 509104

# %%
base_eventos.isnull().sum()
# Out:
# step_id      0
# timestamp    0
# action       0
# user_id      0
# dtype: int64

# %%
base_submissao.isnull().sum()
# Out:
# step_id              0
# timestamp            0
# submission_status    0
# user_id              0
# dtype: int64

# %%
# %matplotlib inline
base_eventos.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'step_id'}>,
#         <Axes: title={'center': 'timestamp'}>],
#        [<Axes: title={'center': 'user_id'}>, <Axes: >]], dtype=object)

# %%
# %matplotlib inline
base_submissao.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'step_id'}>,
#         <Axes: title={'center': 'timestamp'}>],
#        [<Axes: title={'center': 'user_id'}>, <Axes: >]], dtype=object)

# %%
base_submissao["submission_status"].value_counts()
# Out:
# submission_status
# wrong      286399
# correct    222705
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='submission_status',data=base_submissao,color='#9EDDFF')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
base_eventos["action"].value_counts()
# Out:
# action
# viewed             1830830
# discovered          689495
# passed              650331
# started_attempt     310047
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='action',data=base_eventos)
for label in ax.containers:
    ax.bar_label(label)
plt.show()
